# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import os
import pandas as pd

# sys.path.append("..")
# from functions import build_vocab, encode_sequences
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import re
from collections import Counter


def clean_text(text):
    text = text.lower().strip()
    text = re.sub(r'(.)\1+', r'\1\1', text)
    text = re.sub(r'[.,:]', '', text)
    text = re.sub(r'https?://\S+', '', text)
    text = re.sub(r'@\w+', '[name]', text)
    return text

def tokenize_text(text):
    return clean_text(text).split()

nameslist = pd.read_csv('../../data/names.csv')
nameslist = nameslist['name'].tolist()

def build_vocab(texts):
    tokenized_texts = [tokenize_text(text) for text in texts]
    all_words = [word for text in tokenized_texts for word in text if word.isalnum()]
    word_counts = Counter(all_words)
    sorted_words = sorted(word_counts, key=word_counts.get, reverse=True)
    
    top_words = sorted_words[:1000]
    
    word_to_idx = {word: idx+1 for idx, word in enumerate(top_words)}
    word_to_idx['<PAD>'] = 0
    word_to_idx['<UNK>'] = len(word_to_idx)
    word_to_idx['[name]'] = len(word_to_idx)
    return word_to_idx, tokenized_texts

def is_illegal_word(word):
    return any(char.isalnum() == False for char in word) or word not in word_to_idx

def encode_sequences(tokenized_texts, word_to_idx):
    sequences = []
    for tokens in tokenized_texts:
        seq = ['<PAD>']*10
        for i in range(len(tokens)):
            target = tokens[i]  
            if is_illegal_word(target) or is_illegal_word(target):
                seq = ['<PAD>']*10
                break
            if seq[-1] != '<PAD>': 
                encoded_seq = [word_to_idx.get(word, word_to_idx['<UNK>']) for word in seq]
                encoded_target = word_to_idx.get(target, word_to_idx['<UNK>'])
                # print(seq)
                sequences.append((encoded_seq, encoded_target))
            seq.append(target)
            seq.pop(0)
    return sequences

folder_path = '../../data/x'
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
csv_files = sorted(csv_files)[:50]  

dfs = []
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)

texts = df['text'].tolist()

print(f"Loaded {len(texts)} text samples from CSV.")

word_to_idx, tokenized_texts = build_vocab(texts)
sequences = encode_sequences(tokenized_texts, word_to_idx)

print(f"Vocabulary size: {len(word_to_idx)}")
print(f"Number of sequences: {len(sequences)}")
# Out:
# Loaded 498575 text samples from CSV.
# Vocabulary size: 1003
# Number of sequences: 707412

# %%
class TextDataset(Dataset):
    def __init__(self, sequences):
        self.sequences = sequences
    
    def __len__(self):
        return len(self.sequences)
    
    def __getitem__(self, idx):
        sequence, target = self.sequences[idx]
        return torch.tensor(sequence), torch.tensor(target)

class NextWordGRU(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, num_layers, dropout_prob=0.3, repetition_penalty=1.0):
        super(NextWordGRU, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.gru = nn.GRU(embed_size, hidden_size, num_layers, batch_first=True)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(hidden_size, vocab_size)
        self.repetition_penalty = repetition_penalty
    
    def forward(self, x):
        x = self.embedding(x)
        gru_out, _ = self.gru(x)
        gru_out = self.dropout(gru_out[:, -1, :]) 
        out = self.fc(gru_out)
        
        if self.repetition_penalty != 1.0:
            for i in range(out.size(0)):
                for token in x[i]:
                    out[i, token] /= self.repetition_penalty
        
        return out


train_sequences, val_sequences = train_test_split(sequences, test_size=0.2, random_state=42)

train_dataset = TextDataset(train_sequences)
val_dataset = TextDataset(val_sequences)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
idx_to_word = {idx: word for word, idx in word_to_idx.items()}

for i in range(100):
    sequence, target = val_dataset[i]
    sequence_words = [idx_to_word[idx.item()] for idx in sequence]
    target_word = idx_to_word[target.item()]
    print(f"Sequence {i + 1}: {' '.join(sequence_words)} -> {target_word}")
# Out:
# Sequence 1: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> getting ready -> for
# Sequence 2: <PAD> bored out of my mind my plans for the -> evening
# Sequence 3: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> and -> just
# Sequence 4: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> today is going -> to
# Sequence 5: so bored nobody wants to be my friend oh this -> twitter
# Sequence 6: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> have the headache -> from
# Sequence 7: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i really -> want
# Sequence 8: <PAD> <PAD> <PAD> following people around though there are so -> many
# Sequence 9: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i -> miss
# Sequence 10: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> we -> all
# Sequence 11: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> sitting in work while -> the
# Sequence 12: <PAD> <PAD> <PAD> <PAD> <PAD> thank you for making sims -> 3
# Sequence 13: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i -> hate
# Sequence 14: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> who -> is
# Sequence 15: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> what -> a
# Sequence 16: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> is home listening to -> a
# Sequence 17: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> my -> sister
# Sequence 18: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> im soo tired -> lost
# Sequence 19: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> where -> is
# Sequence 20: didnt least i got my facebook ill figure this out -> later
# Sequence 21: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> is off work for -> the
# Sequence 22: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> after using facebook -> twitter
# Sequence 23: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> so -> my
# Sequence 24: <PAD> <PAD> <PAD> <PAD> <PAD> tomorrow is going to be -> really
# Sequence 25: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> already -> missing
# Sequence 26: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> loving the weather -> now
# Sequence 27: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> is it -> that
# Sequence 28: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> bored -> tired
# Sequence 29: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> woke -> up
# Sequence 30: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> omg i feel -> sick
# Sequence 31: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> apparently -> in
# Sequence 32: <PAD> <PAD> <PAD> i am not happy doing work when -> it
# Sequence 33: <PAD> <PAD> <PAD> <PAD> god i miss twitter during the -> day
# Sequence 34: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> watching some updates -> on
# Sequence 35: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> ok -> so
# Sequence 36: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> also the place -> where
# Sequence 37: im like a 7 year old afraid to go to -> school
# Sequence 38: <PAD> <PAD> <PAD> <PAD> so we have to buy a -> new
# Sequence 39: got 5 hours sleep at least s need to find -> out
# Sequence 40: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> last week i -> went
# Sequence 41: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> right should -> stop
# Sequence 42: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> tweeting from the -> airport
# Sequence 43: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> studying -> again
# Sequence 44: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> just -> got
# Sequence 45: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i seriously -> need
# Sequence 46: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i wish i -> was
# Sequence 47: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> all i can -> see
# Sequence 48: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i wonder how much -> money
# Sequence 49: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> with great -> power
# Sequence 50: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> kinda upset with -> the
# Sequence 51: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> just -> finished
# Sequence 52: <PAD> on my way to get lunch i miss my -> brother
# Sequence 53: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i -> cant
# Sequence 54: <PAD> <PAD> <PAD> took a nap now im too lazy -> to
# Sequence 55: i got that it was a reply just wanted to -> know
# Sequence 56: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i -> am
# Sequence 57: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> is happy that -> she
# Sequence 58: <PAD> <PAD> found out that a real cool old friend -> died
# Sequence 59: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> my -> hand
# Sequence 60: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> so i -> went
# Sequence 61: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> head still hurts from -> yesterday
# Sequence 62: <PAD> <PAD> <PAD> <PAD> at home and i have a -> headache
# Sequence 63: <PAD> <PAD> <PAD> <PAD> <PAD> a lil depressed know that -> im
# Sequence 64: <PAD> <PAD> <PAD> <PAD> im really tired but i have -> to
# Sequence 65: <PAD> <PAD> <PAD> <PAD> and god do i really want -> a
# Sequence 66: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> leave school today -> had
# Sequence 67: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> is -> thinking
# Sequence 68: <PAD> <PAD> <PAD> <PAD> 2 or 3 months before i -> see
# Sequence 69: <PAD> <PAD> <PAD> <PAD> <PAD> made it to 1 in -> 1
# Sequence 70: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> how am i still -> 2
# Sequence 71: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> is -> at
# Sequence 72: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> woke -> up
# Sequence 73: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> sad -> that
# Sequence 74: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> off to take -> pictures
# Sequence 75: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> sad this -> weekend
# Sequence 76: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> how long -> should
# Sequence 77: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> okay so -> today
# Sequence 78: <PAD> <PAD> <PAD> is sad disappointed and confused no mood -> to
# Sequence 79: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> worst nights -> sleep
# Sequence 80: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> waiting -> for
# Sequence 81: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> not doing -> much
# Sequence 82: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> feeling -> sick
# Sequence 83: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> never have -> i
# Sequence 84: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> got to learn -> for
# Sequence 85: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> cant wait for -> tuesday
# Sequence 86: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> back -> to
# Sequence 87: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> 1st -> time
# Sequence 88: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i -> feel
# Sequence 89: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> sigh only today -> left
# Sequence 90: <PAD> <PAD> <PAD> <PAD> want to go home but have -> to
# Sequence 91: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> little -> free
# Sequence 92: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i knew this was -> gonna
# Sequence 93: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> is tired of -> summer
# Sequence 94: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> back to -> school
# Sequence 95: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> wants to set -> up
# Sequence 96: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i wish i -> was
# Sequence 97: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> damn -> it
# Sequence 98: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> all ill -> and
# Sequence 99: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> today i find myself -> missing
# Sequence 100: <PAD> terrible headache im so tired i have to study -> and

# %%
def validate_model(model, val_loader, criterion):
    model.eval()  
    total_loss = 0
    total_correct = 0
    with torch.no_grad():  
        for sequences, targets in val_loader:
            sequences, targets = sequences.to(device), targets.to(device)
            
            outputs = model(sequences)
            loss = criterion(outputs, targets)
            total_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total_correct += (predicted == targets).sum().item()

    avg_loss = total_loss / len(val_loader)
    avg_acc = total_correct / len(val_loader.dataset)
    return avg_loss, avg_acc

def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10, patience=3):
    train_losses = []
    val_losses = []
    val_accuracies = []
    best_val_loss = float('inf')
    patience_counter = 0
    best_model = None

    for epoch in range(num_epochs):
        total_loss = 0
        model.train()  

        for batch_idx, (sequences, targets) in enumerate(train_loader):
            sequences, targets = sequences.to(device), targets.to(device)
            
            outputs = model(sequences)
            loss = criterion(outputs, targets)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()

        avg_train_loss = total_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        val_loss, val_acc = validate_model(model, val_loader, criterion)
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)

        print(f'Epoch [{epoch+1}/{num_epochs}] completed, Average Train Loss: {avg_train_loss:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}')

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0  
            best_model = model  
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered")
                break

    model = best_model
    return train_losses, val_losses, val_accuracies


model = NextWordGRU(vocab_size=len(word_to_idx), embed_size=128, hidden_size=256, num_layers=2).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

print("Starting training...")
train_losses, val_losses, val_accuracies = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10)
# Out:
# Starting training...
# Epoch [1/10] completed, Average Train Loss: 4.0731, Validation Loss: 3.7582, Validation Accuracy: 0.2525
# Epoch [2/10] completed, Average Train Loss: 3.7828, Validation Loss: 3.6828, Validation Accuracy: 0.2612
# Epoch [3/10] completed, Average Train Loss: 3.7071, Validation Loss: 3.6463, Validation Accuracy: 0.2647
# Epoch [4/10] completed, Average Train Loss: 3.6613, Validation Loss: 3.6279, Validation Accuracy: 0.2672
# Epoch [5/10] completed, Average Train Loss: 3.6287, Validation Loss: 3.6092, Validation Accuracy: 0.2693
# Epoch [6/10] completed, Average Train Loss: 3.6014, Validation Loss: 3.6046, Validation Accuracy: 0.2694
# Epoch [7/10] completed, Average Train Loss: 3.5785, Validation Loss: 3.5887, Validation Accuracy: 0.2719
# Epoch [8/10] completed, Average Train Loss: 3.5594, Validation Loss: 3.5852, Validation Accuracy: 0.2701
# Epoch [9/10] completed, Average Train Loss: 3.5388, Validation Loss: 3.5779, Validation Accuracy: 0.2730
# Epoch [10/10] completed, Average Train Loss: 3.5231, Validation Loss: 3.5787, Validation Accuracy: 0.2733

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(16, 5))

axs[0].plot(train_losses, label="Train Loss")
axs[0].plot(val_losses, label="Validation Loss")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].set_title("Training and Validation Loss over Epochs")
axs[0].legend()

axs[1].plot(val_accuracies, label="Validation Acc")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Acc")
axs[1].set_title("Validation Acc over Epochs")
axs[1].legend()

plt.show()

# %%
import json

# Save the vocabulary (word_to_idx dictionary)
vocab_save_path = 'vocabulary.json'
with open(vocab_save_path, 'w') as f:
    json.dump(word_to_idx, f)
print(f"Vocabulary saved to {vocab_save_path}")

#save model
model_save_path = 'model_low_vocab.pth'
torch.save(model, model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Vocabulary saved to vocabulary.json
# Model saved to model_low_vocab.pth

# %%
def predict_next_word(model, sequence, idx_to_word):
    model.eval()
    sequence = torch.tensor(sequence).unsqueeze(0).to(device) 
    with torch.no_grad():
        output = model(sequence)
        predicted_idx = torch.argmax(output, dim=1).item()
    return idx_to_word[predicted_idx]


idx_to_word = {idx: word for word, idx in word_to_idx.items()}

indata = [word_to_idx[words] for words in "what did".split()]
print(predict_next_word(model, indata, idx_to_word))
# Out:
# i

# %%
idx_to_word = {idx: word for word, idx in word_to_idx.items()}

for i in range(100):
    sequence, target = val_dataset[i+1000]
    sequence_words = [idx_to_word[idx.item()] for idx in sequence]
    target_word = idx_to_word[target.item()]
    print(f"Sequence {i + 1}: {' '.join(sequence_words)} -> {target_word}")
# Out:
# Sequence 1: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> on the train -> listening
# Sequence 2: <PAD> <PAD> i had a dream last nite that i -> could
# Sequence 3: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i lost -> a
# Sequence 4: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> had two exams -> today
# Sequence 5: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> this time it -> really
# Sequence 6: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> just got done -> playing
# Sequence 7: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> broke -> my
# Sequence 8: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i -> am
# Sequence 9: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i thought -> vacation
# Sequence 10: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i really dont -> want
# Sequence 11: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> sigh -> going
# Sequence 12: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> back -> in
# Sequence 13: to leave for work i wish i didnt have to -> go
# Sequence 14: <PAD> <PAD> <PAD> oh dear oh dear not looking good -> at
# Sequence 15: <PAD> <PAD> is more or less awake hmm could use -> some
# Sequence 16: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> a hard day for -> me
# Sequence 17: <PAD> <PAD> <PAD> <PAD> <PAD> i should probably go to -> sleep
# Sequence 18: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> sad that the -> first
# Sequence 19: <PAD> <PAD> <PAD> <PAD> i wonder where she is now -> the
# Sequence 20: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> on my -> way
# Sequence 21: <PAD> <PAD> you know its not the best of days -> at
# Sequence 22: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> is -> watching
# Sequence 23: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> best -> of
# Sequence 24: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> when -> you
# Sequence 25: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i am so bored -> i
# Sequence 26: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> having cup of -> tea
# Sequence 27: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> gotta go -> to
# Sequence 28: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> on my -> way
# Sequence 29: <PAD> <PAD> <PAD> <PAD> <PAD> i want to start a -> site
# Sequence 30: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i hate that -> feeling
# Sequence 31: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> as much -> as
# Sequence 32: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> english is -> death
# Sequence 33: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> my -> internet
# Sequence 34: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> back to -> work
# Sequence 35: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> mum made -> me
# Sequence 36: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> up and -> at
# Sequence 37: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i need more ice -> but
# Sequence 38: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i have to go -> to
# Sequence 39: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> 4 -> am
# Sequence 40: <PAD> <PAD> <PAD> <PAD> <PAD> the sound of the rain -> is
# Sequence 41: about my dog she isnt well i hope she will -> be
# Sequence 42: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> is -> back
# Sequence 43: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> why do -> i
# Sequence 44: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> home -> from
# Sequence 45: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i miss my -> sister
# Sequence 46: <PAD> what i would give just to get what i -> want
# Sequence 47: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> there -> was
# Sequence 48: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i really need the -> sun
# Sequence 49: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> totally -> just
# Sequence 50: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> happy saturday but -> i
# Sequence 51: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> this saturday i -> have
# Sequence 52: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i -> should
# Sequence 53: <PAD> <PAD> <PAD> <PAD> <PAD> would much like to be -> at
# Sequence 54: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i still -> cry
# Sequence 55: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i -> dont
# Sequence 56: all i gotta do now is pass two huge test -> and
# Sequence 57: <PAD> <PAD> <PAD> <PAD> just got back home from a -> fun
# Sequence 58: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> had -> a
# Sequence 59: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> feels sick -> tell
# Sequence 60: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> hubby -> missed
# Sequence 61: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> hoping to get -> to
# Sequence 62: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> ok i -> see
# Sequence 63: <PAD> <PAD> <PAD> <PAD> i should probably eat something seeing -> as
# Sequence 64: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> my dog died -> fucking
# Sequence 65: <PAD> <PAD> <PAD> <PAD> <PAD> has anyone actually found a -> 4
# Sequence 66: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> bored out of -> my
# Sequence 67: <PAD> <PAD> <PAD> <PAD> just got on the bus and -> im
# Sequence 68: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> was -> not
# Sequence 69: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> at work although i -> think
# Sequence 70: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> ive got -> a
# Sequence 71: <PAD> <PAD> <PAD> <PAD> too much eating in the last -> two
# Sequence 72: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> so much for seeing -> night
# Sequence 73: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> my throat -> hurts
# Sequence 74: <PAD> <PAD> <PAD> <PAD> <PAD> slept through church after my -> week
# Sequence 75: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> just got -> back
# Sequence 76: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> rain again and again -> bad
# Sequence 77: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> has -> a
# Sequence 78: <PAD> <PAD> off college so ill need to get better -> for
# Sequence 79: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> it makes -> me
# Sequence 80: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> oh i forgot who -> asked
# Sequence 81: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> hates having -> to
# Sequence 82: <PAD> <PAD> <PAD> good news the more traffic i get -> on
# Sequence 83: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> you -> know
# Sequence 84: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> is -> i
# Sequence 85: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> looking -> at
# Sequence 86: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i miss my mom -> and
# Sequence 87: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i think i need -> a
# Sequence 88: hate the hospital i hate that little room where they -> do
# Sequence 89: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> wishes that she -> could
# Sequence 90: <PAD> <PAD> <PAD> <PAD> had an awesome run earlier today -> that
# Sequence 91: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> ive lost -> 3
# Sequence 92: today but didnt wanna go out in this weather its -> so
# Sequence 93: <PAD> <PAD> <PAD> <PAD> <PAD> hates the rain but is -> hoping
# Sequence 94: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i -> miss
# Sequence 95: <PAD> <PAD> <PAD> <PAD> i only have 4 more days -> of
# Sequence 96: <PAD> not sure i can take much more of the -> weird
# Sequence 97: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> feeling really sick -> not
# Sequence 98: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i never get to -> play
# Sequence 99: <PAD> <PAD> <PAD> <PAD> <PAD> on the school english again -> but
# Sequence 100: <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> i -> bet
